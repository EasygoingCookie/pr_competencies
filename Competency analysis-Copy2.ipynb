# %% [markdown]
# ## Профессиональные компетенции (подразделения 1612, 1612, 2625)

# %%
dataset = pd.read_excel("first_df.xlsx", engine='openpyxl', sheet_name=0, header=0)

# %%
dataset.head()
# Out:
#                         Сотрудник  \
# 0    Абрамов Василий Владимирович
# 1  Алалыкин Тимофей Александрович
# 2     Анашкин Сергей Владимирович
# 3      Андреев Анатолий Андреевич
# 4           Батуев Егор Андреевич
#
#                                        Подразделение  \
# 0  (2625) Конструкторский отдел масляных трансфор...
# 1  (2625) Конструкторский отдел масляных трансфор...
# 2  (2625) Конструкторский отдел масляных трансфор...
# 3                  (1614) Конструкторское бюро СТ БМ
# 4                  (1614) Конструкторское бюро СТ БМ
#
#                          Должность  \
# 0  Ведущий инженер-конструктор ПРГ
# 1      Ведущий инженер-конструктор
# 2              Инженер-конструктор
# 3              Инженер-конструктор
# 4              Инженер-конструктор
#
#    ПК: Анализ и развитие конкурентных преимуществ продукта  \
# 0                                                  1
# 1                                                  0
# ...

# %%
print(len(dataset))
print(len(dataset.loc[dataset['KPI'] == 0]))
print(len(dataset.loc[dataset['KPI'] == 1]))
# Out:
# 76
# 18
# 58

# %%
feature_names
# Out:
# Index(['ПК: Анализ и развитие конкурентных преимуществ продукта',
#        'ПК: Анализ и систематизация информации (инжен.службы)',
#        'ПК: Выбор оптимальных материалов и комплектующих',
#        'ПК: Генерация и внедрение новых идей',
#        'ПК: Знания сопутствующих IT систем (пример: Elma, заказчик, замены)',
#        'ПК: Основы конструирования трансформатора (реактора)',
#        'ПК: Применение знаний внутренних и внешних стандартов конструирования (ГОСТ, ЕСКД, СП, Инструкции) (специалисты)',
#        'ПК: Применение методов  математического анализа для решения профессиональных задач',
#        'ПК: Проведение авторского надзора',
#        'ПК: Работа в специализированных программных продуктах (специалисты)',
#        'ПК: Работа с текстовыми конструкторскими документами',
#        'ПК: Работа с требованиями заказчика (проработка запроса)',
#        'ПК: Технические расчеты (механические расчеты, тепловые)',
# ...

# %% [markdown]
# ### Матрица корреляций

# %%
datasets
# Out:
#     ПК: Анализ и развитие конкурентных преимуществ продукта  \
# 0                                                   1
# 1                                                   0
# 2                                                   1
# 3                                                   1
# 4                                                   1
# ..                                                ...
# 71                                                  0
# 72                                                  1
# 73                                                  0
# 74                                                  1
# 75                                                  1
#
#     ПК: Анализ и систематизация информации (инжен.службы)  \
# 0                                                   1
# 1                                                   0
# 2                                                   1
# 3                                                   1
# ...

# %%
plt.figure(figsize=(20,20), dpi= 80)
sns.heatmap(datasets.corr(), xticklabels=datasets.corr().columns, yticklabels=datasets.corr().columns, cmap='RdYlGn', center=0, annot=True)

# Decorations
plt.title('Correlogram of features', fontsize=22)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.show()

# %% [markdown]
# ### SHAP

# %%
print("{1:20s} {0:.2f}".format(accuracy_score(labels_test, xgb_clf.predict(test)),'xgboost'))
# Out:
# xgboost              0.85

# %% [markdown]
# #### Графики Shapley values на датасете

# %% [markdown]
# #### Влияние и важность признаков

# %%
shap_values = explainer.shap_values(train)
shap.summary_plot(shap_values, train, feature_names)

# %% [markdown]
# ### Коэффициент Гилфорда

# %%
guilford = pd.DataFrame({"Компетенция": compets, "Коэффициент Гилфорда": results})

# %%
guilford
# Out:
#                                           Компетенция  Коэффициент Гилфорда
# 0   ПК: Анализ и развитие конкурентных преимуществ...              0.113380
# 1   ПК: Анализ и систематизация информации (инжен....              0.121212
# 2    ПК: Выбор оптимальных материалов и комплектующих             -0.065520
# 3                ПК: Генерация и внедрение новых идей              0.013401
# 4   ПК: Знания сопутствующих IT систем (пример: El...              0.023638
# 5   ПК: Основы конструирования трансформатора (реа...             -0.040522
# 6   ПК: Применение знаний внутренних и внешних ста...              0.087608
# 7   ПК: Применение методов  математического анализ...              0.047255
# 8                   ПК: Проведение авторского надзора              0.151763
# 9   ПК: Работа в специализированных программных пр...              0.021026
# 10  ПК: Работа с текстовыми конструкторскими докум...             -0.029361
# ...

# %% [markdown]
# ## Профессиональные компетенции (подразделения 5620-5700)

# %%
print(len(dataset))
print(len(dataset.loc[dataset['KPI'] == 0]))
print(len(dataset.loc[dataset['KPI'] == 1]))
# Out:
# 39
# 14
# 25

# %%
feature_names
# Out:
# Index(['ПК: Аттестация, сертификация, испытания продукции (ПС)',
#        'ПК: Знание и выполнение стандартов предприятия и бизнес-процессов (ПС, ИТ)',
#        'ПК: Знание и соблюдение правил оформления конструкторской документации (ГОСТ ЕСКД)',
#        'ПК: Конструкторское сопровождение производства',
#        'ПК: Работа в CAD-системах (SolidWorks, AutoCAD, Компас) (ПС, ИТ)',
#        'ПК: Техническая проработка заявки заказчика (ПС)',
#        'ПК: Управление качеством выпускаемой продукции (Инж.службы) (ПС)',
#        'ПК: Управление материалоемкостью изделия'],
#       dtype='object')

# %% [markdown]
# ### Матрица корреляций

# %%
datasets = pd.read_excel("second_df_2.xlsx", engine='openpyxl', sheet_name=0, header=0)

# %%
plt.figure(figsize=(20,20), dpi= 80)
sns.heatmap(datasets.corr(), xticklabels=datasets.corr().columns, yticklabels=datasets.corr().columns, cmap='RdYlGn', center=0, annot=True)

# Decorations
plt.title('Correlogram of features', fontsize=22)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.show()

# %% [markdown]
# ### SHAP

# %%
print("{1:20s} {0:.2f}".format(accuracy_score(labels_test, xgb_clf.predict(test)),'xgboost'))
# Out:
# xgboost              0.75

# %% [markdown]
# #### Влияние и важность признаков

# %%
explainer = shap.TreeExplainer(xgb_clf)

# %%
shap_values = explainer.shap_values(train)
shap.summary_plot(shap_values, train, feature_names)

# %% [markdown]
# ### Коэффициент Гилфорда

# %%
guilford = pd.DataFrame({"Компетенция": compets, "Коэффициент Гилфорда": results})

# %%
guilford
# Out:
#                                          Компетенция  Коэффициент Гилфорда
# 0  ПК: Аттестация, сертификация, испытания продук...              0.067612
# 1  ПК: Знание и выполнение стандартов предприятия...              0.352566
# 2  ПК: Знание и соблюдение правил оформления конс...              0.351324
# 3     ПК: Конструкторское сопровождение производства              0.067857
# 4  ПК: Работа в CAD-системах (SolidWorks, AutoCAD...              0.207143
# 5   ПК: Техническая проработка заявки заказчика (ПС)              0.087745
# 6  ПК: Управление качеством выпускаемой продукции...              0.097590
# 7           ПК: Управление материалоемкостью изделия              0.151186

# %% [markdown]
# ## Личностные компетенции

# %% [markdown]
# Из 1200 оценок всего 37 нулей. Огромное количество сотрудников с единичными компетенциями

# %%
datasets = pd.read_excel("third_df_2.xlsx", engine='openpyxl', sheet_name=0, header=0)

# %%
plt.figure(figsize=(10,10), dpi= 80)
sns.heatmap(datasets.corr(), xticklabels=datasets.corr().columns, yticklabels=datasets.corr().columns, cmap='RdYlGn', center=0, annot=True)

# Decorations
plt.title('Correlogram of features', fontsize=22)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.show()

# %%
guilford = pd.DataFrame({"Компетенция": compets, "Коэффициент Гилфорда": results})

# %%
guilford
# Out:
#                       Компетенция  Коэффициент Гилфорда
# 0   ЛК: Нацеленность на результат              0.162650
# 1                  ЛК: Открытость             -0.206593
# 2      ЛК: Познавательный интерес              0.218521
# 3              ЛК: Сотрудничество             -0.367884
# 4  ЛК: Эмоциональная стабильность              0.102190
